# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import scipy 
from scipy import stats,signal
import statsmodels.api as sm

# %% [markdown]
# # Arduino Code

# %%
import serial, time

def Arduino():
    ser = serial.Serial(port='/dev/cu.usbmodem1421', baudrate=38400)

    if ser.isOpen():
        print("{} connected!".format(ser.port))
        try:
            start = time.time()
            
            gryo = {'X':[], 'Y': [], 'Z': []}
            acc = {'X':[], 'Y': [], 'Z': []}
            while True:  
                
                try:
                    line_byte = ser.readline().strip().decode("UTF-8")
                except: continue
                if 'Gryo' in line_byte:
                    try:
                        line = line_byte.split('\t')
                        gryo['X'].append(line[1])
                        gryo['Y'].append(line[2])
                        gryo['Z'].append(line[3])
                        
                    except:
                        continue

                if 'Acc' in line_byte:
                    try:
                        line = line_byte.split('\t')
                        acc['X'].append(line[1])
                        acc['Y'].append(line[2])
                        acc['Z'].append(line[3])
                       
                    except:
                        continue
                    
                    if time.time() - start > 3:
                        break
            return gryo, acc

        except KeyboardInterrupt:
            print("KeyboardInterrupt has been caught.")

# %%
# gryo,acc = Arduino()

# %% [markdown]
# # Data Preprocessing

# %%
gryo_base,acc_base = Arduino()
print(len(gryo_base['X']))
# Out:
# /dev/cu.usbmodem1421 connected!
# 140

# %%
gryo = pd.DataFrame(gryo_base)
acc = pd.DataFrame(acc_base)

col = ['X','Y','Z']

for i in col:
    gryo[[str(i)]] = gryo[[i]].astype(float)
    acc[[str(i)]] = acc[[i]].astype(float)
    
    
# for i in col:
#     gryo[str(i)] = gryo[i] / 32768
#     acc[str(i)] = acc[i] /32768
    
gryo.shape, acc.shape
# Out:
# ((140, 3), (140, 3))

# %%
gryo.plot()

# %%
acc.plot()

# %%
acc.iloc[:128,:][['X']].plot()
acc.iloc[:128,:][['Y']].plot()
acc.iloc[:128,:][['Z']].plot()

# %%
acc.describe()
# Out:
#                   X            Y           Z
# count    140.000000   140.000000  140.000000
# mean   15105.428571 -6864.171429  211.942857
# std      108.860490    85.346348  123.804428
# min    14856.000000 -7164.000000 -128.000000
# 25%    15063.000000 -6893.000000  120.000000
# 50%    15124.000000 -6868.000000  200.000000
# 75%    15165.000000 -6823.000000  277.000000
# max    15352.000000 -6672.000000  508.000000

# %%
gryo.describe()
# Out:
#                 X           Y           Z
# count  140.000000  140.000000  140.000000
# mean   -48.085714   -1.278571  353.500000
# std     16.432327   84.071404   49.955016
# min    -85.000000 -255.000000  213.000000
# 25%    -57.500000  -16.250000  317.750000
# 50%    -47.000000   -6.000000  351.500000
# 75%    -38.750000   11.500000  395.250000
# max    -12.000000  255.000000  467.000000

# %%
def butter_lowpass(cutoff, nyq_freq, order): ##CORRECT
    normal_cutoff = float(cutoff) / nyq_freq
    b, a = signal.butter(order, normal_cutoff, btype='lowpass')
    return b, a

def butter_lowpass_filter(data, cutoff_freq, nyq_freq, order): ##CORRECT
    b, a = butter_lowpass(cutoff_freq, nyq_freq, order=order)
    y = signal.filtfilt(b, a, data) 
    return y


def median_filter(data, f_size): ##CORRECT
    lgth, num_signal = data.shape
    f_data = np.zeros([lgth, num_signal])
    for i in range(num_signal):
        f_data[:,i]=signal.medfilt(data.iloc[:,i], f_size)
    return pd.DataFrame(f_data, columns = ['X','Y','Z'])

def mag(df):
    result = []
    for i in range(df.shape[0]):

        x, y, z = df.iloc[i,:].values
        mag = np.sqrt(x**2 + y**2 + z**2)

        result.append(mag)
    return result




# Fourier Transform
def DFT_slow(x):
    x = np.asarray(x, dtype=float)
    N = x.shape[0]
    n = np.arange(N)
    k = n.reshape((N, 1))
    M = np.exp(-2j * np.pi * k * n / N)
    return np.dot(M, x)

# %% [markdown]
# # Features

# %%
sample_rate = 50
signal_length = 2.56 * sample_rate  # 2.56 seconds
cutoff_frequency = 20.0  # 20Hz


tGyro = pd.DataFrame(columns=['X','Y','Z'])
tAcc = pd.DataFrame(columns=['X','Y','Z'])


med_gryo = median_filter(gryo,3)
med_acc = median_filter(acc,3)


for i in col:
    tGyro[i] = butter_lowpass_filter(med_gryo[i], cutoff_frequency, sample_rate/2, 3)
    tAcc[i] = butter_lowpass_filter(med_acc[i], cutoff_frequency, sample_rate/2, 3)

tBodyGyro = tGyro



tGravityAcc = pd.DataFrame(columns=['X','Y','Z'])
tBodyAcc = pd.DataFrame(columns=['X','Y','Z'])

tBodyAccJerk = pd.DataFrame(columns=['X','Y','Z'])
tBodyGyroJerk = pd.DataFrame(columns=['X','Y','Z'])


for i in col:
    tGravityAcc[i] = butter_lowpass_filter(tAcc[i], 0.3, sample_rate/2, 3)
    tBodyAcc[i] = tAcc[i] - tGravityAcc[i] 
   
    #Derivative
    tBodyAccJerk[i] = tBodyAcc[i].diff()
    tBodyGyroJerk[i] = tBodyGyro[i].diff()
 

tBodyAccJerk.fillna(0, inplace = True)
tBodyGyroJerk.fillna(0, inplace = True)

 



# Magnitude
tBodyAccMag = pd.DataFrame(columns=['tBodyAccMag'])
tBodyAccMag['tBodyAccMag'] =  mag(tBodyAcc)

tGravityAccMag = pd.DataFrame(columns=['tGravityAccMag'])
tGravityAccMag['tGravityAccMag'] = mag(tGravityAcc)

tBodyAccJerkMag = pd.DataFrame(columns=['tBodyAccJerkMag'])
tBodyAccJerkMag['tBodyAccJerkMag'] = mag(tBodyAccJerk)

tBodyGyroMag = pd.DataFrame(columns=['tBodyGyroMag'])
tBodyGyroMag['tBodyGyroMag'] = mag(tBodyGyro)

tBodyGyroJerkMag = pd.DataFrame(columns=['tBodyGyroJerkMag'])
tBodyGyroJerkMag['tBodyGyroJerkMag'] = mag(tBodyGyroJerk)

#CHECKED

    
    
    
# Fourier Transform
fBodyAcc= pd.DataFrame(columns=['X','Y','Z'])
fBodyAccJerk = pd.DataFrame(columns=['X','Y','Z'])
fBodyGyro = pd.DataFrame(columns=['X','Y','Z'])

for i in col:
    fBodyAcc[i] = DFT_slow(tBodyAcc[i]).real    
    fBodyAccJerk[i] = DFT_slow(tBodyAccJerk[i]).real    
    fBodyGyro[i] = DFT_slow(tBodyGyro[i]).real    

fBodyAccMag = pd.DataFrame(columns=['fBodyAccMag'])
fBodyAccMag['fBodyAccMag'] = np.squeeze(DFT_slow(tBodyAccMag)).real    

fBodyAccJerkMag = pd.DataFrame(columns=['fBodyAccJerkMag'])
fBodyAccJerkMag['fBodyAccJerkMag'] = np.squeeze(DFT_slow(tBodyAccJerkMag)).real    

fBodyGyroMag = pd.DataFrame(columns=['fBodyGyroMag'])
fBodyGyroMag['fBodyGyroMag'] = np.squeeze(DFT_slow(tBodyGyroMag)).real    

fBodyGyroJerkMag = pd.DataFrame(columns=['fBodyGyroJerkMag'])
fBodyGyroJerkMag['fBodyGyroJerkMag'] = np.squeeze(DFT_slow(tBodyGyroJerkMag)).real

# %% [markdown]
# ### Jerk

# %%
# tBodyAccJerk[i] = tBodyAcc[i].diff()

plt.figure(1)
plt.plot(tBodyGyro['X'], label= 'X')
plt.plot(tBodyGyro['Y'], label= 'Y')
plt.plot(tBodyGyro['Z'], label= 'Z')
plt.legend()


plt.figure(2)
plt.title('Derived')
plt.plot(tBodyGyroJerk['X'].diff(),label= 'X')
plt.plot(tBodyGyroJerk['Y'].diff(),label= 'Y')
plt.plot(tBodyGyroJerk['Z'].diff(),label= 'Z')
plt.legend()

plt.show()

# %% [markdown]
# ### Magnitude

# %%
tBodyAccMag = pd.DataFrame(columns=['tBodyAccMag'])
tBodyAccMag['tBodyAccMag'] =  mag(tBodyAcc)

# %%
plt.figure(1)
tBodyAccMag.plot()


plt.figure(2)
tBodyAcc.plot()

plt.show()

# %%
tBodyAcc.iloc[4,:].values
# Out:
# array([-61.58881531,   9.98187875, 121.38885885])

# %%
tBodyAcc.head()
# Out:
#            X          Y           Z
# 0  19.437698  27.724462    6.183821
# 1  24.386653  20.852794   63.969348
# 2  14.181990   6.229932  154.360592
# 3 -39.601499 -11.122639  155.462259
# 4 -61.588815   9.981879  121.388859

# %%
# Mean Calculation
def mean(x):
    mean_x = np.mean(x)
    return mean_x

# Standard Deviation Calculation
def std_dev(x):
    std_x = np.std(x)
    return std_x

# Median Absolute Deviation Calculation
def mad(x):
    mad_x = np.median(np.abs(x - np.median(x)))
    return mad_x
    
# Min Calculation
def min_value(x):
    return min(x)

# Max Calculation
def max_value(x):
    return max(x)

# Signal Magnitude Area Calculation
def sma(signal):
    x,y,z = signal['X'],signal['Y'],signal['Z']
    abs_x = np.absolute(x)
    abs_y = np.absolute(y)
    abs_z = np.absolute(z)
    return np.mean(abs_x + abs_y + abs_z)

#one Column
def sma2(signal):
    abs_ = np.absolute(signal)
    return np.mean(abs_)


# Energy measure. Sum of the squares divided by the number of values. 
def energy_measure(x):
    em_x = np.mean(np.square(x))
    return em_x

# Inter-quartile range Calculation
def inter_quartile_range(x):
    iqr_x = np.subtract(*np.percentile(x, [75, 25]))
    return iqr_x

# entropy(): Signal entropy
def entropy(x):
    entr = stats.entropy(x)
    
    if stats.entropy(x) == -np.inf:
        entr = -1
    if stats.entropy(x) == np.inf:
        entr = 1
        
    return entr

# arCoeff(): Autorregresion coefficients with Burg order equal to 4
def arCoeff(signal,order):
    _, sigma = sm.regression.linear_model.burg(signal, order=order)
    return sigma

# correlation(): correlation coefficient between two signals
def coor(signal):
    corr = tBodyAcc.corr()
    x_y = corr.loc['X','Y']
    x_z = corr.loc['X','Z']
    y_z = corr.loc['Y','Z']
    
    return x_y, x_z, y_z


# maxInds(): index of the frequency component with largest magnitude
def maxInds(x):
    idx_x = np.argmax(x)
    return idx_x


# meanFreq(): Weighted average of the frequency components to obtain a mean frequency
def meanFreq(signal):
    return np.mean(signal)


# skewness(): skewness of the frequency domain signal 
def skewness(x):
    skew_x=stats.skew(x)
    return 0

# kurtosis(): kurtosis of the frequency domain signal 
def kurtosis(x):
    kurt_x = stats.kurtosis(x,fisher=False)
    return 0
    

# bandsEnergy(): Energy of a frequency interval within the 64 bins of the FFT of each window.
def bandpower(x, fmin, fmax, fs=1):
    f, Pxx = scipy.signal.periodogram(x,fs=fs)
    ind_min = np.argmax(f > fmin) - 1
    ind_max = np.argmax(f > fmax) - 1
    return np.trapz(Pxx[ind_min: ind_max], f[ind_min: ind_max])

# angle(): Angle between to vectors.
def angle_calc(vector_1,vector_2):
    unit_vector_1 = vector_1 / np.linalg.norm(vector_1)
    unit_vector_2 = vector_2 / np.linalg.norm(vector_2)
    dot_product = np.dot(unit_vector_1, unit_vector_2)
    angle = np.arccos(dot_product)
    return angle

def angle(signal):
    g = 9.80665
    try:
        l = [g for _ in range(signal.shape[0])] 
    except:
        l = g
    
    angle_value = angle_calc(signal, l)

    return angle_value

# %%
col = ['X','Y','Z']
for i in col:  
    print(entropy(tBodyAcc[i]))
    for count in range(1,5):
        print(arCoeff(tBodyAcc[i], count))
# Out:
# 4.7004750308755
# 3.310958949519692e-07
# 1.168859869451079e-07
# 4.7279872701053326e-08
# 2.4741341077914586e-08
# 4.7004775865620365
# 3.1663468254861365e-07
# 1.0764938750883048e-07
# 5.171806803209058e-08
# 2.620437298025019e-08
# 4.70012859452718
# 1.9776552221190587e-06
# 5.255161216604596e-07
# 2.4040579615933644e-07
# 8.568777753065258e-08

# %% [markdown]
# # Feature Collections

# %%
def feature_40(signal, name):
    l = [ 'mean_X', 'mean_Y', 'mean_Z',
         'std_X','std_Y', 'std_Z',
         'mad_X','mad_Y', 'mad_Z',
         'max_X','max_Y', 'max_Z',
         'min_X','min_Y', 'min_Z',
         'sma',
         'energy_X', 'energy_Y','energy_Z',
         'iqr_X','iqr_Y','iqr_Z',
         'entropy_X', 'entropy_Y', 'entropy_Z',
         'X_1','X_2','X_3','X_4','Y_1','Y_2','Y_3','Y_4', 'Z_1','Z_2','Z_3','Z_4',
         'correlation_x_y','correlation_x_z', 'correlation_y_z'
         ]
    col = ['X','Y','Z']
    fet_40 = dict()
    
    for i in col:
        fet_40['mean_' + i ] = mean(signal[i])
        fet_40['std_' + i ] = std_dev(signal[i])
        fet_40['mad_' + i ] = mad(signal[i])
        fet_40['max_' + i ] = max_value(signal[i])
        fet_40['min_' + i ] = min_value(signal[i])
        fet_40['energy_' + i ] = energy_measure(signal[i])
        fet_40['iqr_' + i ] = inter_quartile_range(signal[i])
        fet_40['entropy_' + i ] = entropy(signal[i])
        
        for count in range(1,5):
            fet_40[i + '_' + str(count)] = arCoeff(signal[i], count)
        
    fet_40['sma'] = sma(signal)
    fet_40['correlation_x_y'] = coor(signal)[0]
    fet_40['correlation_x_z'] = coor(signal)[1]
    fet_40['correlation_y_z'] = coor(signal)[2]
    
    res = {}
    for key in l:
        res[name+'_'+key] = fet_40[key]
    
    return res

def feature_13(signal, name):
    fet_13 = dict()
    
    fet_13[name + '_mean'] = mean(signal)
    fet_13[name + '_std'] = std_dev(signal)
    fet_13[name + '_mad'] = mad(signal)
    fet_13[name + '_max'] = max_value(signal)
    fet_13[name + '_min'] = min_value(signal)
    fet_13[name + '_sma'] = sma2(signal)
    fet_13[name + '_energy'] = energy_measure(signal)
    fet_13[name + '_iqr'] = inter_quartile_range(signal)
    fet_13[name + '_entropy'] = entropy(signal)
    
    for count in range(1,5):
        fet_13[name + '_AR_' + str(count)] = arCoeff(signal, count)
    
    return fet_13

def feature_80(signal, name):
    l = ['mean_X', 'mean_Y', 'mean_Z',
         'std_X','std_Y', 'std_Z',
         'mad_X','mad_Y', 'mad_Z',
         'max_X','max_Y', 'max_Z',
         'min_X','min_Y', 'min_Z',
         'sma',
         'energy_X', 'energy_Y','energy_Z',
         'iqr_X', 'iqr_Y', 'iqr_Z',
         'entropy_X', 'entropy_Y', 'entropy_Z',
         'maxInds_X', 'maxInds_Y', 'maxInds_Z',
         'meanFreq_X', 'meanFreq_Y', 'meanFreq_Z',
         'skewness_X', 'kurtosis_X', 'skewness_Y', 'kurtosis_Y', 'skewness_Z', 'kurtosis_Z',
         'bandpower_X-1-8', 'bandpower_X-9-16', 'bandpower_X-17-24', 'bandpower_X-25-32', 'bandpower_X-33-40', 
         'bandpower_X-41-48', 'bandpower_X-49-56', 'bandpower_X-57-64', 
         'bandpower_X-1-16', 'bandpower_X-17-32', 'bandpower_X-33-48', 'bandpower_X-49-64',
         'bandpower_X-1-24', 'bandpower_X-25-48',
         
         'bandpower_Y-1-8', 'bandpower_Y-9-16', 'bandpower_Y-17-24', 'bandpower_Y-25-32', 'bandpower_Y-33-40', 
         'bandpower_Y-41-48', 'bandpower_Y-49-56', 'bandpower_Y-57-64', 
         'bandpower_Y-1-16', 'bandpower_Y-17-32', 'bandpower_Y-33-48', 'bandpower_Y-49-64', 
         'bandpower_Y-1-24', 'bandpower_Y-25-48',
         
         'bandpower_Z-1-8', 'bandpower_Z-9-16', 'bandpower_Z-17-24', 'bandpower_Z-25-32', 'bandpower_Z-33-40', 
         'bandpower_Z-41-48', 'bandpower_Z-49-56', 'bandpower_Z-57-64', 
         'bandpower_Z-1-16', 'bandpower_Z-17-32', 'bandpower_Z-33-48', 'bandpower_Z-49-64', 
         'bandpower_Z-1-24', 'bandpower_Z-25-48' 
         ]

    col = ['X','Y','Z']
    fet_80 = dict()
    
    for i in col:
        fet_80['mean_' + i ] = mean(signal[i])
        fet_80['std_' + i ] = std_dev(signal[i])
        fet_80['mad_' + i ] = mad(signal[i])
        fet_80['max_' + i ] = max_value(signal[i])
        fet_80['min_' + i ] = min_value(signal[i])
        fet_80['energy_' + i ] = energy_measure(signal[i])
        fet_80['iqr_' + i ] = inter_quartile_range(signal[i])
        fet_80['entropy_' + i ] = entropy(signal[i])
        
        fet_80['maxInds_' + i ] = maxInds(signal[i])
        fet_80['meanFreq_' + i ] = meanFreq(signal[i])
        
        fet_80['skewness_' + i] = skewness(signal[i])
        fet_80['kurtosis_' + i] = kurtosis(signal[i])
        

        for j in range(1,65,8):
            fet_80['bandpower_' + i + '-' + str(j) + '-' + str(j+7) ] = bandpower(signal[i], j, j+7)
            
        for k in range(1,65,16):
            fet_80['bandpower_' + i + '-' + str(k) + '-' + str(k+15) ] = bandpower(signal[i], k, k+15)

        for q in range(1,65,24):
            if q+23 > 65:break
            fet_80['bandpower_' + i + '-' + str(q) + '-' + str(q+23)] = bandpower(signal[i], q, q+23) 
        
        
    fet_80['sma'] = sma(signal)

    
    res = {}
    for key in l:
        res[name+'_'+key] = fet_80[key]
    
    return res

def feature_13_MAG(signal, name):
    fet_mag = dict()
    
    fet_mag[name + '_mean'] = mean(signal)
    fet_mag[name + '_std'] = std_dev(signal)
    fet_mag[name + '_mad'] = mad(signal)
    fet_mag[name + '_max'] = max_value(signal)
    fet_mag[name + '_min'] = min_value(signal)
    fet_mag[name + '_sma'] = sma2(signal)
    fet_mag[name + '_energy'] = energy_measure(signal)
    fet_mag[name + '_iqr'] = inter_quartile_range(signal)
    fet_mag[name + '_entropy'] = entropy(signal)
    
    fet_mag[name + '_maxInds' ] = maxInds(signal)
    fet_mag[name + '_meanFreq'] = meanFreq(signal)
    fet_mag[name + '_skewness'] = skewness(signal)
    fet_mag[name + '_kurtosis'] = kurtosis(signal)    
    
    return fet_mag

def last_features():
    feat = dict()
    
    feat['tBodyAccMean_angle'] = angle(tBodyAcc.mean())
    feat['tBodyAccJerkMean_angle'] = angle(tBodyAccJerk.mean())
    feat['tBodyGyroMean_angle'] = angle(tBodyGyro.mean())
    feat['tBodyGyroJerkMean_angle'] = angle(tBodyGyroJerk.mean())
    
    feat['tGravityAcc_X_angle'] = angle(tGravityAcc['X'])
    feat['tGravityAcc_Y_angle'] = angle(tGravityAcc['Y'])
    feat['tGravityAcc_Z_angle'] = angle(tGravityAcc['Z'])

    return feat

# %%
def collectFeatures():
    res = dict()
    
    feat40 = {'tBodyAcc':tBodyAcc,'tGravityAcc': tGravityAcc,'tBodyAccJerk':tBodyAccJerk,
              'tBodyGyro':tBodyGyro,'tBodyGyroJerk': tBodyGyroJerk} 
    for k,v in feat40.items():
        res.update(feature_40(v,k ))
    
    
    
    feat13 = {'tBodyAccMag': tBodyAccMag,'tGravityAccMag': tGravityAccMag,
              'tBodyAccJerkMag': tBodyAccJerkMag,'tBodyGyroMag': tBodyGyroMag,
              'tBodyGyroJerkMag':tBodyGyroJerkMag}
    for k,v in feat13.items():
        res.update(feature_13(v[k],k ))
    
    
    
    feat_80 = {'fBodyAcc': fBodyAcc, 'fBodyAccJerk': fBodyAccJerk, 'fBodyGyro': fBodyGyro}
    for k,v in feat_80.items():
        res.update(feature_80(v,k ))
    
    
    
    feat13_mag = {'fBodyAccMag':fBodyAccMag,'fBodyAccJerkMag': fBodyAccJerkMag,
                  'fBodyGyroMag': fBodyGyroMag, 'fBodyGyroJerkMag': fBodyGyroJerkMag}
    for k,v in feat13_mag.items():
        res.update(feature_13_MAG(v[k],k ))
    
    res.update(last_features())
    return res

# %%
if __name__ == '__main__':
    

    result = collectFeatures()
    result = pd.DataFrame(result, index=[0])
    result.to_csv('test_data.csv', index = False, header = False)

# %%
pd.options.display.max_columns = 9999
pd.options.display.float_format = '{:,.5f}'.format
result
# Out:
#    tBodyAcc_mean_X  tBodyAcc_mean_Y  tBodyAcc_mean_Z  tBodyAcc_std_X  \
# 0          0.00415          0.49634          0.04508         0.00093
#
#    tBodyAcc_std_Y  tBodyAcc_std_Z  tBodyAcc_mad_X  tBodyAcc_mad_Y  \
# 0         0.00081         0.00187         0.00052         0.00044
#
#    tBodyAcc_mad_Z  tBodyAcc_max_X  tBodyAcc_max_Y  tBodyAcc_max_Z  \
# 0         0.00122         0.00620         0.49869         0.05028
#
#    tBodyAcc_min_X  tBodyAcc_min_Y  tBodyAcc_min_Z  tBodyAcc_sma  \
# 0         0.00053         0.49407         0.04087       0.54558
#
#    tBodyAcc_energy_X  tBodyAcc_energy_Y  tBodyAcc_energy_Z  tBodyAcc_iqr_X  \
# 0            0.00002            0.24636            0.00204         0.00103
#
#    tBodyAcc_iqr_Y  tBodyAcc_iqr_Z  tBodyAcc_entropy_X  tBodyAcc_entropy_Y  \
# 0         0.00086         0.00239             4.71674             4.74493
#
#    tBodyAcc_entropy_Z  tBodyAcc_X_1  tBodyAcc_X_2  tBodyAcc_X_3  tBodyAcc_X_4  \
# 0             4.74407       0.00000       0.00000       0.00000       0.00000
#
#    tBodyAcc_Y_1  tBodyAcc_Y_2  tBodyAcc_Y_3  tBodyAcc_Y_4  tBodyAcc_Z_1  \
# 0       0.00000       0.00000       0.00000       0.00000       0.00000
#
#    tBodyAcc_Z_2  tBodyAcc_Z_3  tBodyAcc_Z_4  tBodyAcc_correlation_x_y  \
# 0       0.00000       0.00000       0.00000                   0.21258
#
#    tBodyAcc_correlation_x_z  tBodyAcc_correlation_y_z  tGravityAcc_mean_X  \
# 0                  -0.05439                  -0.01648             0.00466
#
#    tGravityAcc_mean_Y  tGravityAcc_mean_Z  tGravityAcc_std_X  \
# 0             0.49629             0.04005            0.00003
#
#    tGravityAcc_std_Y  tGravityAcc_std_Z  tGravityAcc_mad_X  tGravityAcc_mad_Y  \
# 0            0.00000            0.00031            0.00001            0.00000
#
#    tGravityAcc_mad_Z  tGravityAcc_max_X  tGravityAcc_max_Y  tGravityAcc_max_Z  \
# 0            0.00015            0.00472            0.49630            0.04033
#
#    tGravityAcc_min_X  tGravityAcc_min_Y  tGravityAcc_min_Z  tGravityAcc_sma  \
# 0            0.00463            0.49628            0.03930          0.54100
#
#    tGravityAcc_energy_X  tGravityAcc_energy_Y  tGravityAcc_energy_Z  \
# 0               0.00002               0.24631               0.00160
#
#    tGravityAcc_iqr_X  tGravityAcc_iqr_Y  tGravityAcc_iqr_Z  \
# 0            0.00004            0.00001            0.00046
#
#    tGravityAcc_entropy_X  tGravityAcc_entropy_Y  tGravityAcc_entropy_Z  \
# 0                4.74492                4.74493                4.74490
#
#    tGravityAcc_X_1  tGravityAcc_X_2  tGravityAcc_X_3  tGravityAcc_X_4  \
# 0          0.00000          0.00000          0.00000          0.00000
#
#    tGravityAcc_Y_1  tGravityAcc_Y_2  tGravityAcc_Y_3  tGravityAcc_Y_4  \
# 0          0.00000          0.00000          0.00000          0.00000
#
#    tGravityAcc_Z_1  tGravityAcc_Z_2  tGravityAcc_Z_3  tGravityAcc_Z_4  \
# 0          0.00000          0.00000          0.00000          0.00000
#
#    tGravityAcc_correlation_x_y  tGravityAcc_correlation_x_z  \
# 0                      0.21258                     -0.05439
#
#    tGravityAcc_correlation_y_z  tBodyAccJerk_mean_X  tBodyAccJerk_mean_Y  \
# 0                     -0.01648             -0.00000             -0.00000
#
#    tBodyAccJerk_mean_Z  tBodyAccJerk_std_X  tBodyAccJerk_std_Y  \
# 0              0.00003             0.00060             0.00056
#
#    tBodyAccJerk_std_Z  tBodyAccJerk_mad_X  tBodyAccJerk_mad_Y  \
# 0             0.00103             0.00029             0.00035
#
#    tBodyAccJerk_mad_Z  tBodyAccJerk_max_X  tBodyAccJerk_max_Y  \
# 0             0.00078             0.00231             0.00130
#
#    tBodyAccJerk_max_Z  tBodyAccJerk_min_X  tBodyAccJerk_min_Y  \
# 0             0.00226            -0.00155            -0.00172
#
#    tBodyAccJerk_min_Z  tBodyAccJerk_sma  tBodyAccJerk_energy_X  \
# 0            -0.00206           0.00172                0.00000
#
#    tBodyAccJerk_energy_Y  tBodyAccJerk_energy_Z  tBodyAccJerk_iqr_X  \
# 0                0.00000                0.00000             0.00058
#
#    tBodyAccJerk_iqr_Y  tBodyAccJerk_iqr_Z  tBodyAccJerk_entropy_X  \
# 0             0.00064             0.00152                      -1
#
#    tBodyAccJerk_entropy_Y  tBodyAccJerk_entropy_Z  tBodyAccJerk_X_1  \
# 0                      -1                      -1           0.00000
#
#    tBodyAccJerk_X_2  tBodyAccJerk_X_3  tBodyAccJerk_X_4  tBodyAccJerk_Y_1  \
# 0           0.00000           0.00000           0.00000           0.00000
#
#    tBodyAccJerk_Y_2  tBodyAccJerk_Y_3  tBodyAccJerk_Y_4  tBodyAccJerk_Z_1  \
# 0           0.00000           0.00000           0.00000           0.00000
#
#    tBodyAccJerk_Z_2  tBodyAccJerk_Z_3  tBodyAccJerk_Z_4  \
# 0           0.00000           0.00000           0.00000
#
#    tBodyAccJerk_correlation_x_y  tBodyAccJerk_correlation_x_z  \
# 0                       0.21258                      -0.05439
#
#    tBodyAccJerk_correlation_y_z  tBodyGyro_mean_X  tBodyGyro_mean_Y  \
# 0                      -0.01648          -0.00252          -0.00009
#
#    tBodyGyro_mean_Z  tBodyGyro_std_X  tBodyGyro_std_Y  tBodyGyro_std_Z  \
# 0           0.01138          0.00259          0.00160          0.00021
#
#    tBodyGyro_mad_X  tBodyGyro_mad_Y  tBodyGyro_mad_Z  tBodyGyro_max_X  \
# 0          0.00142          0.00052          0.00013          0.00456
#
#    tBodyGyro_max_Y  tBodyGyro_max_Z  tBodyGyro_min_X  tBodyGyro_min_Y  \
# 0          0.00288          0.01203         -0.00968         -0.00496
#
#    tBodyGyro_min_Z  tBodyGyro_sma  tBodyGyro_energy_X  tBodyGyro_energy_Y  \
# 0          0.01088        0.01545             0.00001             0.00000
#
#    tBodyGyro_energy_Z  tBodyGyro_iqr_X  tBodyGyro_iqr_Y  tBodyGyro_iqr_Z  \
# 0             0.00013          0.00291          0.00129          0.00025
#
#    tBodyGyro_entropy_X  tBodyGyro_entropy_Y  tBodyGyro_entropy_Z  \
# 0                   -1                   -1              4.74477
#
#    tBodyGyro_X_1  tBodyGyro_X_2  tBodyGyro_X_3  tBodyGyro_X_4  tBodyGyro_Y_1  \
# 0        0.00000        0.00000        0.00000        0.00000        0.00000
#
#    tBodyGyro_Y_2  tBodyGyro_Y_3  tBodyGyro_Y_4  tBodyGyro_Z_1  tBodyGyro_Z_2  \
# 0        0.00000        0.00000        0.00000        0.00000        0.00000
#
#    tBodyGyro_Z_3  tBodyGyro_Z_4  tBodyGyro_correlation_x_y  \
# 0        0.00000        0.00000                    0.21258
#
#    tBodyGyro_correlation_x_z  tBodyGyro_correlation_y_z  tBodyGyroJerk_mean_X  \
# 0                   -0.05439                   -0.01648              -0.00007
#
#    tBodyGyroJerk_mean_Y  tBodyGyroJerk_mean_Z  tBodyGyroJerk_std_X  \
# 0              -0.00000               0.00000              0.00168
#
#    tBodyGyroJerk_std_Y  tBodyGyroJerk_std_Z  tBodyGyroJerk_mad_X  \
# 0              0.00082              0.00013              0.00117
#
#    tBodyGyroJerk_mad_Y  tBodyGyroJerk_mad_Z  tBodyGyroJerk_max_X  \
# 0              0.00041              0.00007              0.00419
#
#    tBodyGyroJerk_max_Y  tBodyGyroJerk_max_Z  tBodyGyroJerk_min_X  \
# 0              0.00158              0.00039             -0.00438
#
#    tBodyGyroJerk_min_Y  tBodyGyroJerk_min_Z  tBodyGyroJerk_sma  \
# 0             -0.00268             -0.00050            0.00204
#
#    tBodyGyroJerk_energy_X  tBodyGyroJerk_energy_Y  tBodyGyroJerk_energy_Z  \
# 0                 0.00000                 0.00000                 0.00000
#
#    tBodyGyroJerk_iqr_X  tBodyGyroJerk_iqr_Y  tBodyGyroJerk_iqr_Z  \
# 0              0.00225              0.00074              0.00015
#
#    tBodyGyroJerk_entropy_X  tBodyGyroJerk_entropy_Y  tBodyGyroJerk_entropy_Z  \
# 0                       -1                       -1                       -1
#
#    tBodyGyroJerk_X_1  tBodyGyroJerk_X_2  tBodyGyroJerk_X_3  tBodyGyroJerk_X_4  \
# 0            0.00000            0.00000            0.00000            0.00000
#
#    tBodyGyroJerk_Y_1  tBodyGyroJerk_Y_2  tBodyGyroJerk_Y_3  tBodyGyroJerk_Y_4  \
# 0            0.00000            0.00000            0.00000            0.00000
#
#    tBodyGyroJerk_Z_1  tBodyGyroJerk_Z_2  tBodyGyroJerk_Z_3  tBodyGyroJerk_Z_4  \
# 0            0.00000            0.00000            0.00000            0.00000
#
#    tBodyGyroJerk_correlation_x_y  tBodyGyroJerk_correlation_x_z  \
# 0                        0.21258                       -0.05439
#
#    tBodyGyroJerk_correlation_y_z  tBodyAccMag_mean  tBodyAccMag_std  \
# 0                       -0.01648           0.49841          0.00082
#
#    tBodyAccMag_mad  tBodyAccMag_max  tBodyAccMag_min  tBodyAccMag_sma  \
# 0          0.00047          0.50067          0.49632          0.49841
#
#    tBodyAccMag_energy  tBodyAccMag_iqr  tBodyAccMag_entropy  tBodyAccMag_AR_1  \
# 0             0.24841          0.00096              4.74493           0.00000
#
#    tBodyAccMag_AR_2  tBodyAccMag_AR_3  tBodyAccMag_AR_4  tGravityAccMag_mean  \
# 0           0.00000           0.00000           0.00000              0.49793
#
#    tGravityAccMag_std  tGravityAccMag_mad  tGravityAccMag_max  \
# 0             0.00003             0.00001             0.49796
#
#    tGravityAccMag_min  tGravityAccMag_sma  tGravityAccMag_energy  \
# 0             0.49786             0.49793                0.24793
#
#    tGravityAccMag_iqr  tGravityAccMag_entropy  tGravityAccMag_AR_1  \
# 0             0.00004                 4.74493              0.00000
#
#    tGravityAccMag_AR_2  tGravityAccMag_AR_3  tGravityAccMag_AR_4  \
# 0              0.00000              0.00000              0.00000
#
#    tBodyAccJerkMag_mean  tBodyAccJerkMag_std  tBodyAccJerkMag_mad  \
# 0               0.00120              0.00055              0.00037
#
#    tBodyAccJerkMag_max  tBodyAccJerkMag_min  tBodyAccJerkMag_sma  \
# 0              0.00271              0.00000              0.00120
#
#    tBodyAccJerkMag_energy  tBodyAccJerkMag_iqr  tBodyAccJerkMag_entropy  \
# 0                 0.00000              0.00072                  4.63529
#
#    tBodyAccJerkMag_AR_1  tBodyAccJerkMag_AR_2  tBodyAccJerkMag_AR_3  \
# 0               0.00000               0.00000               0.00000
#
#    tBodyAccJerkMag_AR_4  tBodyGyroMag_mean  tBodyGyroMag_std  \
# 0               0.00000            0.01202           0.00080
#
#    tBodyGyroMag_mad  tBodyGyroMag_max  tBodyGyroMag_min  tBodyGyroMag_sma  \
# 0           0.00039           0.01537           0.01098           0.01202
#
#    tBodyGyroMag_energy  tBodyGyroMag_iqr  tBodyGyroMag_entropy  \
# 0              0.00015           0.00078               4.74280
#
#    tBodyGyroMag_AR_1  tBodyGyroMag_AR_2  tBodyGyroMag_AR_3  tBodyGyroMag_AR_4  \
# 0            0.00000            0.00000            0.00000            0.00000
#
#    tBodyGyroJerkMag_mean  tBodyGyroJerkMag_std  tBodyGyroJerkMag_mad  \
# 0                0.00160               0.00098               0.00060
#
#    tBodyGyroJerkMag_max  tBodyGyroJerkMag_min  tBodyGyroJerkMag_sma  \
# 0               0.00438               0.00000               0.00160
#
#    tBodyGyroJerkMag_energy  tBodyGyroJerkMag_iqr  tBodyGyroJerkMag_entropy  \
# 0                  0.00000               0.00129                   4.55364
#
#    tBodyGyroJerkMag_AR_1  tBodyGyroJerkMag_AR_2  tBodyGyroJerkMag_AR_3  \
# 0                0.00000                0.00000                0.00000
#
#    tBodyGyroJerkMag_AR_4  fBodyAcc_mean_X  fBodyAcc_mean_Y  fBodyAcc_mean_Z  \
# 0                0.00000          0.00441          0.49647          0.04087
#
#    fBodyAcc_std_X  fBodyAcc_std_Y  fBodyAcc_std_Z  fBodyAcc_mad_X  \
# 0         0.04480         5.29950         0.48201         0.00025
#
#    fBodyAcc_mad_Y  fBodyAcc_mad_Z  fBodyAcc_max_X  fBodyAcc_max_Y  \
# 0         0.00019         0.00044         0.47781        57.07960
#
#    fBodyAcc_max_Z  fBodyAcc_min_X  fBodyAcc_min_Y  fBodyAcc_min_Z  \
# 0         5.18468        -0.01693        -0.01884        -0.06856
#
#    fBodyAcc_sma  fBodyAcc_energy_X  fBodyAcc_energy_Y  fBodyAcc_energy_Z  \
# 0       0.56149            0.00203           28.33118            0.23400
#
#    fBodyAcc_iqr_X  fBodyAcc_iqr_Y  fBodyAcc_iqr_Z  fBodyAcc_entropy_X  \
# 0         0.00136         0.00053         0.00160                  -1
#
#    fBodyAcc_entropy_Y  fBodyAcc_entropy_Z  fBodyAcc_maxInds_X  \
# 0                  -1                  -1                   0
#
#    fBodyAcc_maxInds_Y  fBodyAcc_maxInds_Z  fBodyAcc_meanFreq_X  \
# 0                   0                   0              0.00441
#
#    fBodyAcc_meanFreq_Y  fBodyAcc_meanFreq_Z  fBodyAcc_skewness_X  \
# 0              0.49647              0.04087                    0
#
#    fBodyAcc_kurtosis_X  fBodyAcc_skewness_Y  fBodyAcc_kurtosis_Y  \
# 0                    0                    0                    0
#
#    fBodyAcc_skewness_Z  fBodyAcc_kurtosis_Z  fBodyAcc_bandpower_X-1-8  \
# 0                    0                    0                   0.00000
#
#    fBodyAcc_bandpower_X-9-16  fBodyAcc_bandpower_X-17-24  \
# 0                    0.00000                     0.00000
#
#    fBodyAcc_bandpower_X-25-32  fBodyAcc_bandpower_X-33-40  \
# 0                     0.00000                     0.00000
#
#    fBodyAcc_bandpower_X-41-48  fBodyAcc_bandpower_X-49-56  \
# 0                     0.00000                     0.00000
#
#    fBodyAcc_bandpower_X-57-64  fBodyAcc_bandpower_X-1-16  \
# 0                     0.00000                    0.00000
#
#    fBodyAcc_bandpower_X-17-32  fBodyAcc_bandpower_X-33-48  \
# 0                     0.00000                     0.00000
#
#    fBodyAcc_bandpower_X-49-64  fBodyAcc_bandpower_X-1-24  \
# 0                     0.00000                    0.00000
#
#    fBodyAcc_bandpower_X-25-48  fBodyAcc_bandpower_Y-1-8  \
# 0                     0.00000                   0.00000
#
#    fBodyAcc_bandpower_Y-9-16  fBodyAcc_bandpower_Y-17-24  \
# 0                    0.00000                     0.00000
#
#    fBodyAcc_bandpower_Y-25-32  fBodyAcc_bandpower_Y-33-40  \
# 0                     0.00000                     0.00000
#
#    fBodyAcc_bandpower_Y-41-48  fBodyAcc_bandpower_Y-49-56  \
# 0                     0.00000                     0.00000
#
#    fBodyAcc_bandpower_Y-57-64  fBodyAcc_bandpower_Y-1-16  \
# 0                     0.00000                    0.00000
#
#    fBodyAcc_bandpower_Y-17-32  fBodyAcc_bandpower_Y-33-48  \
# 0                     0.00000                     0.00000
#
#    fBodyAcc_bandpower_Y-49-64  fBodyAcc_bandpower_Y-1-24  \
# 0                     0.00000                    0.00000
#
#    fBodyAcc_bandpower_Y-25-48  fBodyAcc_bandpower_Z-1-8  \
# 0                     0.00000                   0.00000
#
#    fBodyAcc_bandpower_Z-9-16  fBodyAcc_bandpower_Z-17-24  \
# 0                    0.00000                     0.00000
#
#    fBodyAcc_bandpower_Z-25-32  fBodyAcc_bandpower_Z-33-40  \
# 0                     0.00000                     0.00000
#
#    fBodyAcc_bandpower_Z-41-48  fBodyAcc_bandpower_Z-49-56  \
# 0                     0.00000                     0.00000
#
#    fBodyAcc_bandpower_Z-57-64  fBodyAcc_bandpower_Z-1-16  \
# 0                     0.00000                    0.00000
#
#    fBodyAcc_bandpower_Z-17-32  fBodyAcc_bandpower_Z-33-48  \
# 0                     0.00000                     0.00000
#
#    fBodyAcc_bandpower_Z-49-64  fBodyAcc_bandpower_Z-1-24  \
# 0                     0.00000                    0.00000
#
#    fBodyAcc_bandpower_Z-25-48  fBodyAccJerk_mean_X  fBodyAccJerk_mean_Y  \
# 0                     0.00000              0.00000             -0.00000
#
#    fBodyAccJerk_mean_Z  fBodyAccJerk_std_X  fBodyAccJerk_std_Y  \
# 0             -0.00000             0.00447             0.00397
#
#    fBodyAccJerk_std_Z  fBodyAccJerk_mad_X  fBodyAccJerk_mad_Y  \
# 0             0.00656             0.00024             0.00031
#
#    fBodyAccJerk_mad_Z  fBodyAccJerk_max_X  fBodyAccJerk_max_Y  \
# 0             0.00162             0.01105             0.01021
#
#    fBodyAccJerk_max_Z  fBodyAccJerk_min_X  fBodyAccJerk_min_Y  \
# 0             0.01871            -0.01484            -0.01438
#
#    fBodyAccJerk_min_Z  fBodyAccJerk_sma  fBodyAccJerk_energy_X  \
# 0            -0.01793           0.00878                0.00002
#
#    fBodyAccJerk_energy_Y  fBodyAccJerk_energy_Z  fBodyAccJerk_iqr_X  \
# 0                0.00002                0.00004             0.00141
#
#    fBodyAccJerk_iqr_Y  fBodyAccJerk_iqr_Z  fBodyAccJerk_entropy_X  \
# 0             0.00065             0.00311                      -1
#
#    fBodyAccJerk_entropy_Y  fBodyAccJerk_entropy_Z  fBodyAccJerk_maxInds_X  \
# 0                      -1                      -1                      22
#
#    fBodyAccJerk_maxInds_Y  fBodyAccJerk_maxInds_Z  fBodyAccJerk_meanFreq_X  \
# 0                      95                      17                  0.00000
#
#    fBodyAccJerk_meanFreq_Y  fBodyAccJerk_meanFreq_Z  fBodyAccJerk_skewness_X  \
# 0                 -0.00000                 -0.00000                        0
#
#    fBodyAccJerk_kurtosis_X  fBodyAccJerk_skewness_Y  fBodyAccJerk_kurtosis_Y  \
# 0                        0                        0                        0
#
#    fBodyAccJerk_skewness_Z  fBodyAccJerk_kurtosis_Z  \
# 0                        0                        0
#
#    fBodyAccJerk_bandpower_X-1-8  fBodyAccJerk_bandpower_X-9-16  \
# 0                       0.00000                        0.00000
#
#    fBodyAccJerk_bandpower_X-17-24  fBodyAccJerk_bandpower_X-25-32  \
# 0                         0.00000                         0.00000
#
#    fBodyAccJerk_bandpower_X-33-40  fBodyAccJerk_bandpower_X-41-48  \
# 0                         0.00000                         0.00000
#
#    fBodyAccJerk_bandpower_X-49-56  fBodyAccJerk_bandpower_X-57-64  \
# 0                         0.00000                         0.00000
#
#    fBodyAccJerk_bandpower_X-1-16  fBodyAccJerk_bandpower_X-17-32  \
# 0                        0.00000                         0.00000
#
#    fBodyAccJerk_bandpower_X-33-48  fBodyAccJerk_bandpower_X-49-64  \
# 0                         0.00000                         0.00000
#
#    fBodyAccJerk_bandpower_X-1-24  fBodyAccJerk_bandpower_X-25-48  \
# 0                        0.00000                         0.00000
#
#    fBodyAccJerk_bandpower_Y-1-8  fBodyAccJerk_bandpower_Y-9-16  \
# 0                       0.00000                        0.00000
#
#    fBodyAccJerk_bandpower_Y-17-24  fBodyAccJerk_bandpower_Y-25-32  \
# 0                         0.00000                         0.00000
#
#    fBodyAccJerk_bandpower_Y-33-40  fBodyAccJerk_bandpower_Y-41-48  \
# 0                         0.00000                         0.00000
#
#    fBodyAccJerk_bandpower_Y-49-56  fBodyAccJerk_bandpower_Y-57-64  \
# 0                         0.00000                         0.00000
#
#    fBodyAccJerk_bandpower_Y-1-16  fBodyAccJerk_bandpower_Y-17-32  \
# 0                        0.00000                         0.00000
#
#    fBodyAccJerk_bandpower_Y-33-48  fBodyAccJerk_bandpower_Y-49-64  \
# 0                         0.00000                         0.00000
#
#    fBodyAccJerk_bandpower_Y-1-24  fBodyAccJerk_bandpower_Y-25-48  \
# 0                        0.00000                         0.00000
#
#    fBodyAccJerk_bandpower_Z-1-8  fBodyAccJerk_bandpower_Z-9-16  \
# 0                       0.00000                        0.00000
#
#    fBodyAccJerk_bandpower_Z-17-24  fBodyAccJerk_bandpower_Z-25-32  \
# 0                         0.00000                         0.00000
#
#    fBodyAccJerk_bandpower_Z-33-40  fBodyAccJerk_bandpower_Z-41-48  \
# 0                         0.00000                         0.00000
#
#    fBodyAccJerk_bandpower_Z-49-56  fBodyAccJerk_bandpower_Z-57-64  \
# 0                         0.00000                         0.00000
#
#    fBodyAccJerk_bandpower_Z-1-16  fBodyAccJerk_bandpower_Z-17-32  \
# 0                        0.00000                         0.00000
#
#    fBodyAccJerk_bandpower_Z-33-48  fBodyAccJerk_bandpower_Z-49-64  \
# 0                         0.00000                         0.00000
#
#    fBodyAccJerk_bandpower_Z-1-24  fBodyAccJerk_bandpower_Z-25-48  \
# 0                        0.00000                         0.00000
#
#    fBodyGyro_mean_X  fBodyGyro_mean_Y  fBodyGyro_mean_Z  fBodyGyro_std_X  \
# 0          -0.00193          -0.00015           0.01187          0.03372
#
#    fBodyGyro_std_Y  fBodyGyro_std_Z  fBodyGyro_mad_X  fBodyGyro_mad_Y  \
# 0          0.01310          0.12146          0.00057          0.00049
#
#    fBodyGyro_mad_Z  fBodyGyro_max_X  fBodyGyro_max_Y  fBodyGyro_max_Z  \
# 0          0.00009          0.06074          0.03933          1.30863
#
#    fBodyGyro_min_X  fBodyGyro_min_Y  fBodyGyro_min_Z  fBodyGyro_sma  \
# 0         -0.28999         -0.04036         -0.00306        0.03291
#
#    fBodyGyro_energy_X  fBodyGyro_energy_Y  fBodyGyro_energy_Z  \
# 0             0.00114             0.00017             0.01489
#
#    fBodyGyro_iqr_X  fBodyGyro_iqr_Y  fBodyGyro_iqr_Z  fBodyGyro_entropy_X  \
# 0          0.00232          0.00108          0.00062                   -1
#
#    fBodyGyro_entropy_Y  fBodyGyro_entropy_Z  fBodyGyro_maxInds_X  \
# 0                   -1                   -1                    5
#
#    fBodyGyro_maxInds_Y  fBodyGyro_maxInds_Z  fBodyGyro_meanFreq_X  \
# 0                  114                    0              -0.00193
#
#    fBodyGyro_meanFreq_Y  fBodyGyro_meanFreq_Z  fBodyGyro_skewness_X  \
# 0              -0.00015               0.01187                     0
#
#    fBodyGyro_kurtosis_X  fBodyGyro_skewness_Y  fBodyGyro_kurtosis_Y  \
# 0                     0                     0                     0
#
#    fBodyGyro_skewness_Z  fBodyGyro_kurtosis_Z  fBodyGyro_bandpower_X-1-8  \
# 0                     0                     0                    0.00000
#
#    fBodyGyro_bandpower_X-9-16  fBodyGyro_bandpower_X-17-24  \
# 0                     0.00000                      0.00000
#
#    fBodyGyro_bandpower_X-25-32  fBodyGyro_bandpower_X-33-40  \
# 0                      0.00000                      0.00000
#
#    fBodyGyro_bandpower_X-41-48  fBodyGyro_bandpower_X-49-56  \
# 0                      0.00000                      0.00000
#
#    fBodyGyro_bandpower_X-57-64  fBodyGyro_bandpower_X-1-16  \
# 0                      0.00000                     0.00000
#
#    fBodyGyro_bandpower_X-17-32  fBodyGyro_bandpower_X-33-48  \
# 0                      0.00000                      0.00000
#
#    fBodyGyro_bandpower_X-49-64  fBodyGyro_bandpower_X-1-24  \
# 0                      0.00000                     0.00000
#
#    fBodyGyro_bandpower_X-25-48  fBodyGyro_bandpower_Y-1-8  \
# 0                      0.00000                    0.00000
#
#    fBodyGyro_bandpower_Y-9-16  fBodyGyro_bandpower_Y-17-24  \
# 0                     0.00000                      0.00000
#
#    fBodyGyro_bandpower_Y-25-32  fBodyGyro_bandpower_Y-33-40  \
# 0                      0.00000                      0.00000
#
#    fBodyGyro_bandpower_Y-41-48  fBodyGyro_bandpower_Y-49-56  \
# 0                      0.00000                      0.00000
#
#    fBodyGyro_bandpower_Y-57-64  fBodyGyro_bandpower_Y-1-16  \
# 0                      0.00000                     0.00000
#
#    fBodyGyro_bandpower_Y-17-32  fBodyGyro_bandpower_Y-33-48  \
# 0                      0.00000                      0.00000
#
#    fBodyGyro_bandpower_Y-49-64  fBodyGyro_bandpower_Y-1-24  \
# 0                      0.00000                     0.00000
#
#    fBodyGyro_bandpower_Y-25-48  fBodyGyro_bandpower_Z-1-8  \
# 0                      0.00000                    0.00000
#
#    fBodyGyro_bandpower_Z-9-16  fBodyGyro_bandpower_Z-17-24  \
# 0                     0.00000                      0.00000
#
#    fBodyGyro_bandpower_Z-25-32  fBodyGyro_bandpower_Z-33-40  \
# 0                      0.00000                      0.00000
#
#    fBodyGyro_bandpower_Z-41-48  fBodyGyro_bandpower_Z-49-56  \
# 0                      0.00000                      0.00000
#
#    fBodyGyro_bandpower_Z-57-64  fBodyGyro_bandpower_Z-1-16  \
# 0                      0.00000                     0.00000
#
#    fBodyGyro_bandpower_Z-17-32  fBodyGyro_bandpower_Z-33-48  \
# 0                      0.00000                      0.00000
#
#    fBodyGyro_bandpower_Z-49-64  fBodyGyro_bandpower_Z-1-24  \
# 0                      0.00000                     0.00000
#
#    fBodyGyro_bandpower_Z-25-48  fBodyAccMag_mean  fBodyAccMag_std  \
# 0                      0.00000           0.49817          5.32158
#
#    fBodyAccMag_mad  fBodyAccMag_max  fBodyAccMag_min  fBodyAccMag_sma  \
# 0          0.00022         57.31708         -0.02151          0.50204
#
#    fBodyAccMag_energy  fBodyAccMag_iqr  fBodyAccMag_entropy  \
# 0            28.56742          0.00061                   -1
#
#    fBodyAccMag_maxInds  fBodyAccMag_meanFreq  fBodyAccMag_skewness  \
# 0                    0               0.49817                     0
#
#    fBodyAccMag_kurtosis  fBodyAccJerkMag_mean  fBodyAccJerkMag_std  \
# 0                     0               0.00000              0.01348
#
#    fBodyAccJerkMag_mad  fBodyAccJerkMag_max  fBodyAccJerkMag_min  \
# 0              0.00201              0.13799             -0.01179
#
#    fBodyAccJerkMag_sma  fBodyAccJerkMag_energy  fBodyAccJerkMag_iqr  \
# 0              0.00422                 0.00018              0.00403
#
#    fBodyAccJerkMag_entropy  fBodyAccJerkMag_maxInds  fBodyAccJerkMag_meanFreq  \
# 0                       -1                        0                   0.00000
#
#    fBodyAccJerkMag_skewness  fBodyAccJerkMag_kurtosis  fBodyGyroMag_mean  \
# 0                         0                         0            0.01203
#
#    fBodyGyroMag_std  fBodyGyroMag_mad  fBodyGyroMag_max  fBodyGyroMag_min  \
# 0           0.12850           0.00180           1.38247          -0.01560
#
#    fBodyGyroMag_sma  fBodyGyroMag_energy  fBodyGyroMag_iqr  \
# 0           0.01621              0.01666           0.00409
#
#    fBodyGyroMag_entropy  fBodyGyroMag_maxInds  fBodyGyroMag_meanFreq  \
# 0                    -1                     0                0.01203
#
#    fBodyGyroMag_skewness  fBodyGyroMag_kurtosis  fBodyGyroJerkMag_mean  \
# 0                      0                      0                0.00000
#
#    fBodyGyroJerkMag_std  fBodyGyroJerkMag_mad  fBodyGyroJerkMag_max  \
# 0               0.01853               0.00384               0.18393
#
#    fBodyGyroJerkMag_min  fBodyGyroJerkMag_sma  fBodyGyroJerkMag_energy  \
# 0              -0.02182               0.00711                  0.00034
#
#    fBodyGyroJerkMag_iqr  fBodyGyroJerkMag_entropy  fBodyGyroJerkMag_maxInds  \
# 0               0.00889                        -1                         0
#
#    fBodyGyroJerkMag_meanFreq  fBodyGyroJerkMag_skewness  \
# 0                    0.00000                          0
#
#    fBodyGyroJerkMag_kurtosis  tBodyAccMean_angle  tBodyAccJerkMean_angle  \
# 0                          0             0.88666                 1.13747
#
#    tBodyGyroMean_angle  tBodyGyroJerkMean_angle  tGravityAcc_X_angle  \
# 0              1.12154                  2.21686              0.00547
#
#    tGravityAcc_Y_angle  tGravityAcc_Z_angle
# 0              0.00001              0.00764

# %%
# Visualize
plt.figure(figsize=(11, 9))
plt.plot(tBodyAcc.X, color='red', label="Original signal, {} samples".format(signal_length))
plt.plot(fBodyAcc.X, color='blue', label="Filtered low-pass with cutoff frequency of {} Hz".format(cutoff_frequency))
# plt.plot(diff, color='gray', label="What has been removed")

plt.title("Signal and its filtering")
plt.xlabel('Time (1/50th sec. per tick)')
plt.ylabel('Amplitude')
plt.legend()
plt.show()
